# %% [markdown]
# ## TASK 1: IMPORT PACKAGES AND LOAD DATA

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
path = '/Users/PC/Documents/NamNguyen/WorkSpace/Others/Projects for Data Science/Project_1/data/'
df = pd.read_csv(path + 'sales2019_1.csv')
#dataframe 
df.head(20)  # Show the number of rows you want
# Out:
#    Order ID                     Product Quantity Ordered Price Each  \
# 0    141234                      iPhone                1        700
# 1    141235    Lightning Charging Cable                1      14.95
# 2    141236            Wired Headphones                2      11.99
# 3    141237            27in FHD Monitor                1     149.99
# 4    141238            Wired Headphones                1      11.99
# 5    141239      AAA Batteries (4-pack)                1       2.99
# 6    141240      27in 4K Gaming Monitor                1     389.99
# 7    141241        USB-C Charging Cable                1      11.95
# 8    141242  Bose SoundSport Headphones                1      99.99
# 9    141243    Apple Airpods Headphones                1        150
# 10   141244    Apple Airpods Headphones                1        150
# 11   141245          Macbook Pro Laptop                1       1700
# 12   141246      AAA Batteries (4-pack)                3       2.99
# ...

# %%
# dataframe.dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9723 entries, 0 to 9722
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          9697 non-null   object
#  1   Product           9697 non-null   object
#  2   Quantity Ordered  9697 non-null   object
#  3   Price Each        9697 non-null   object
#  4   Order Date        9697 non-null   object
#  5   Purchase Address  9697 non-null   object
# dtypes: object(6)
# memory usage: 455.9+ KB

# %% [markdown]
# ## TASK 2: CLEAN AND PREPROCESS DATA

# %% [markdown]
# ### Task 2.1 Merge 12-month data

# %%
frames = []
total_length = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        filepath = path + file
        df1 = pd.read_csv(filepath)
        frames.append(df1)
        result = pd.concat(frames)
        each_month_length = len(df1.index)
        total_length.append(each_month_length)

df = result
df.to_csv('annualSales2019.csv', index = False)

# %% [markdown]
# ### 2.2 ADD 'MONTH' COLUMN

# %%
df['Month'] = df['Order Date'].str.slice(0,2,1)   # start = 0, stop = 2, step = 1
df.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address Month
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215    01
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035    01
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301    01

# %%
set(df['Month'])
# Out:
# {'01',
#  '02',
#  '03',
#  '04',
#  '05',
#  '06',
#  '07',
#  '08',
#  '09',
#  '10',
#  '11',
#  '12',
#  'Or',
#  nan}

# %% [markdown]
# ### 2.3 Get rid of NaN and Or values

# %%
# Get rid of NaN value
df = df.dropna(how = 'all')
# Get rid of OR value
df = df[df['Month'] != 'Or']
df
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       141234                    iPhone                1        700
# 1       141235  Lightning Charging Cable                1      14.95
# 2       141236          Wired Headphones                2      11.99
# 3       141237          27in FHD Monitor                1     149.99
# 4       141238          Wired Headphones                1      11.99
# ...        ...                       ...              ...        ...
# 11681   259353    AAA Batteries (4-pack)                3       2.99
# 11682   259354                    iPhone                1        700
# 11683   259355                    iPhone                1        700
# 11684   259356    34in Ultrawide Monitor                1     379.99
# 11685   259357      USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address Month
# 0      01/22/19 21:25          944 Walnut St, Boston, MA 02215    01
# ...

# %% [markdown]
# ## TASK 3: Reporting

# %% [markdown]
# ### 3.1 What was the best month for sales ? How much was earned that month ?

# %%
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'], downcast='integer')
df['Price Each'] = pd.to_numeric(df['Price Each'], downcast='float')

# %%
print(df['Quantity Ordered'].dtypes)
print(df['Price Each'].dtypes)
# Out:
# int8
# float32

# %%
# Create Sales Column
df['Sales'] = df['Quantity Ordered'] * df['Price Each']
df
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       141234                    iPhone                 1  700.000000
# 1       141235  Lightning Charging Cable                 1   14.950000
# 2       141236          Wired Headphones                 2   11.990000
# 3       141237          27in FHD Monitor                 1  149.990005
# 4       141238          Wired Headphones                 1   11.990000
# ...        ...                       ...               ...         ...
# 11681   259353    AAA Batteries (4-pack)                 3    2.990000
# 11682   259354                    iPhone                 1  700.000000
# 11683   259355                    iPhone                 1  700.000000
# 11684   259356    34in Ultrawide Monitor                 1  379.989990
# 11685   259357      USB-C Charging Cable                 1   11.950000
#
#            Order Date                         Purchase Address Month  \
# ...

# %%
# Move column Sales after column Price Each
moving_column = df.pop('Sales')
df.insert(4, 'Sales', moving_column)
df
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       141234                    iPhone                 1  700.000000
# 1       141235  Lightning Charging Cable                 1   14.950000
# 2       141236          Wired Headphones                 2   11.990000
# 3       141237          27in FHD Monitor                 1  149.990005
# 4       141238          Wired Headphones                 1   11.990000
# ...        ...                       ...               ...         ...
# 11681   259353    AAA Batteries (4-pack)                 3    2.990000
# 11682   259354                    iPhone                 1  700.000000
# 11683   259355                    iPhone                 1  700.000000
# 11684   259356    34in Ultrawide Monitor                 1  379.989990
# 11685   259357      USB-C Charging Cable                 1   11.950000
#
#             Sales      Order Date                         Purchase Address  \
# ...

# %%
sales_value = df.groupby('Month').sum()['Sales']
sales_value
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_22244\748672857.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales_value = df.groupby('Month').sum()['Sales']
# Month
# 01    1822256.75
# 02    2202022.50
# 03    2807100.25
# 04    3390670.25
# 05    3152606.75
# 06    2577802.25
# 07    2647775.75
# 08    2244467.75
# 09    2097560.00
# 10    3736726.75
# 11    3199603.25
# 12    4613443.50
# Name: Sales, dtype: float32

# %%
sales_value = df.groupby('Month').sum()['Sales']
sales_value.max()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_22244\612898388.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales_value = df.groupby('Month').sum()['Sales']
# 4613443.5

# %%
# Draw bar chart
months = range(1,13)
plt.bar(x = months, height= sales_value)
plt.xticks(months)
plt.xlabel('Months')
plt.ylabel('Sales in USD')
plt.show()

# %% [markdown]
# ### 3.2 What city has the best sales?

# %%
city_address = lambda address:address.split(',')[1]

# %%
df['City'] = df['Purchase Address'].apply(city_address)
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#         Sales      Order Date                       Purchase Address Month  \
# 0  700.000000  01/22/19 21:25        944 Walnut St, Boston, MA 02215    01
# 1   14.950000  01/28/19 14:15       185 Maple St, Portland, OR 97035    01
# 2   23.980000  01/17/19 13:33  538 Adams St, San Francisco, CA 94016    01
# 3  149.990005  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    01
# 4   11.990000  01/25/19 11:59          387 10th St, Austin, TX 73301    01
#
#              City
# 0          Boston
# 1        Portland
# 2   San Francisco
# 3     Los Angeles
# ...

# %%
df.groupby('City').sum()['Sales']
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_22244\2445985979.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('City').sum()['Sales']
# City
#  Atlanta          2795498.50
#  Austin           1819581.75
#  Boston           3661642.00
#  Dallas           2767975.50
#  Los Angeles      5452571.00
#  New York City    4664317.50
#  Portland         2320490.50
#  San Francisco    8262204.00
#  Seattle          2747755.50
# Name: Sales, dtype: float32

# %%
sales_value_city = df.groupby('City').sum()['Sales']
sales_value_city.max()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_22244\3451846393.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales_value_city = df.groupby('City').sum()['Sales']
# 8262204.0

# %%
cities = []
for city, sale in sales_value_city.items():
    cities.append(city)
print(cities)
# Out:
# [' Atlanta', ' Austin', ' Boston', ' Dallas', ' Los Angeles', ' New York City', ' Portland', ' San Francisco', ' Seattle']

# %%
# Draw a bar chart 
plt.bar(x = cities, height= sales_value_city)
plt.xticks(cities, rotation = 50, size = 7)
plt.yticks(size = 7)
plt.xlabel('Cities')
plt.ylabel('Sales values per city')
# Out:
# Text(0, 0.5, 'Sales values per city')

# %%
print(cities)
print(sales_value_city)
# Out:
# [' Atlanta', ' Austin', ' Boston', ' Dallas', ' Los Angeles', ' New York City', ' Portland', ' San Francisco', ' Seattle']
# City
#  Atlanta          2795498.50
#  Austin           1819581.75
#  Boston           3661642.00
#  Dallas           2767975.50
#  Los Angeles      5452571.00
#  New York City    4664317.50
#  Portland         2320490.50
#  San Francisco    8262204.00
#  Seattle          2747755.50
# Name: Sales, dtype: float32

# %% [markdown]
# ### 3.3 What time should we display ads to maximize the likelihood of customer's buying products?

# %%
print(df['Order Date'].dtypes)
# Out:
# object

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df['Hours'] = df['Order Date'].dt.hour
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#         Sales          Order Date                       Purchase Address  \
# 0  700.000000 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215
# 1   14.950000 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035
# 2   23.980000 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016
# 3  149.990005 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001
# 4   11.990000 2019-01-25 11:59:00          387 10th St, Austin, TX 73301
#
#   Month            City  Hours
# 0    01          Boston     21
# 1    01        Portland     14
# ...

# %%
sales_value_hours = df.groupby('Hours').count()['Sales']
hours = []
for hour, sale in sales_value_hours.items():
    hours.append(hour)

# %%
# Draw line chart
plt.plot(hours, sales_value_hours)
plt.grid()
plt.xticks(hours, rotation = 45, size = 7)
plt.yticks(size = 7)
plt.xlabel('Hours')
plt.ylabel('Sales per hour')
plt.show()

# %% [markdown]
# #### Answer: The time should we display ads is from 11-12 AM and 19-20 AM

# %% [markdown]
# ### 3.4 What products are the most often sold together ?

# %% [markdown]
# #### --> Products have the same OrderID or OrderDate/Purchase Address

# %%
df.head(10)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   141234                      iPhone                 1  700.000000
# 1   141235    Lightning Charging Cable                 1   14.950000
# 2   141236            Wired Headphones                 2   11.990000
# 3   141237            27in FHD Monitor                 1  149.990005
# 4   141238            Wired Headphones                 1   11.990000
# 5   141239      AAA Batteries (4-pack)                 1    2.990000
# 6   141240      27in 4K Gaming Monitor                 1  389.989990
# 7   141241        USB-C Charging Cable                 1   11.950000
# 8   141242  Bose SoundSport Headphones                 1   99.989998
# 9   141243    Apple Airpods Headphones                 1  150.000000
#
#         Sales          Order Date                         Purchase Address  \
# 0  700.000000 2019-01-22 21:25:00          944 Walnut St, Boston, MA 02215
# ...

# %%
df_dup = df[df['Order ID'].duplicated(keep = False)]
df_dup
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 41      141275      USB-C Charging Cable                 1       11.95
# 42      141275          Wired Headphones                 1       11.99
# 57      141290  Apple Airpods Headphones                 1      150.00
# 58      141290     AA Batteries (4-pack)                 3        3.84
# 133     141365           Vareebadd Phone                 1      400.00
# ...        ...                       ...               ...         ...
# 11628   259303     AA Batteries (4-pack)                 1        3.84
# 11639   259314          Wired Headphones                 1       11.99
# 11640   259314    AAA Batteries (4-pack)                 2        2.99
# 11677   259350              Google Phone                 1      600.00
# 11678   259350      USB-C Charging Cable                 1       11.95
#
#         Sales          Order Date                        Purchase Address  \
# ...

# %%
groupProduct = lambda product: ', '.join(product)

# %%
df_dup['All Products'] = df_dup.groupby('Order ID')['Product'].transform(groupProduct)
df_dup.head()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_22244\1322959905.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dup['All Products'] = df_dup.groupby('Order ID')['Product'].transform(groupProduct)
#     Order ID                   Product  Quantity Ordered  Price Each   Sales  \
# 41    141275      USB-C Charging Cable                 1       11.95   11.95
# 42    141275          Wired Headphones                 1       11.99   11.99
# 57    141290  Apple Airpods Headphones                 1      150.00  150.00
# 58    141290     AA Batteries (4-pack)                 3        3.84   11.52
# 133   141365           Vareebadd Phone                 1      400.00  400.00
#
# ...

# %%
df_dup[['Order ID', 'All Products']].drop_duplicates()
# Out:
#       Order ID                                       All Products
# 41      141275             USB-C Charging Cable, Wired Headphones
# 57      141290    Apple Airpods Headphones, AA Batteries (4-pack)
# 133     141365                  Vareebadd Phone, Wired Headphones
# 153     141384                 Google Phone, USB-C Charging Cable
# 220     141450           Google Phone, Bose SoundSport Headphones
# ...        ...                                                ...
# 11617   259296  Apple Airpods Headphones, Apple Airpods Headph...
# 11619   259297  iPhone, Lightning Charging Cable, Lightning Ch...
# 11627   259303      34in Ultrawide Monitor, AA Batteries (4-pack)
# 11639   259314           Wired Headphones, AAA Batteries (4-pack)
# 11677   259350                 Google Phone, USB-C Charging Cable
#
# [7136 rows x 2 columns]

# %%
df_dup['All Products'].value_counts().head(10)
# Out:
# iPhone, Lightning Charging Cable                        1764
# Google Phone, USB-C Charging Cable                      1712
# iPhone, Wired Headphones                                 722
# Vareebadd Phone, USB-C Charging Cable                    624
# Google Phone, Wired Headphones                           606
# iPhone, Apple Airpods Headphones                         572
# Google Phone, Bose SoundSport Headphones                 322
# Google Phone, USB-C Charging Cable, Wired Headphones     231
# Vareebadd Phone, Wired Headphones                        208
# iPhone, Lightning Charging Cable, Wired Headphones       168
# Name: All Products, dtype: int64

# %% [markdown]
# ### 3.5 What product sold the most? Why do you think it sold the most ?

# %%
df.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   141234                    iPhone                 1  700.000000
# 1   141235  Lightning Charging Cable                 1   14.950000
# 2   141236          Wired Headphones                 2   11.990000
# 3   141237          27in FHD Monitor                 1  149.990005
# 4   141238          Wired Headphones                 1   11.990000
#
#         Sales          Order Date                       Purchase Address  \
# 0  700.000000 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215
# 1   14.950000 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035
# 2   23.980000 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016
# 3  149.990005 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001
# 4   11.990000 2019-01-25 11:59:00          387 10th St, Austin, TX 73301
#
#   Month            City  Hours
# 0    01          Boston     21
# 1    01        Portland     14
# ...

# %%
all_products = df.groupby('Product')['Quantity Ordered'].sum()
all_products
# Out:
# Product
# 20in Monitor                   4129
# 27in 4K Gaming Monitor         6244
# 27in FHD Monitor               7550
# 34in Ultrawide Monitor         6199
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# Flatscreen TV                  4819
# Google Phone                   5532
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      23217
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# USB-C Charging Cable          23975
# Vareebadd Phone                2068
# Wired Headphones              20557
# iPhone                         6849
# Name: Quantity Ordered, dtype: int64

# %%
products_ls = [product for product, quant in all_products.items()]
plt.bar(products_ls, all_products)
plt.xticks(products_ls, rotation = 90, size = 8)
plt.xlabel('Products')
plt.ylabel('Quantity')
plt.show()
